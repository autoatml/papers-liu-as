# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

file_paths = [
    "r2scan_rdf_and_jr.txt",
    "rdf_as_beta.csv"
]

fig, ax = plt.subplots(figsize=(2.4, 2.4))
data = pd.read_csv(file_paths[0], delim_whitespace=True, skiprows=1, header=None)
x = data[0]
y = data[3]
plt.plot(x, y, color='red', linestyle='-', label='r2SCAN')

data = pd.read_csv(
    file_paths[1],
    sep=",",
    header=None,
    names=[0, 1],     
    skiprows=1,     
    engine="python"
)
x = data[0]
y = data[1]
plt.plot(x, y, color='gray', linestyle='--', dashes=[2, 1], label='Expt.')

ax.set_xlabel(r"Distance")
ax.set_ylabel(r"${J}$(${r}$) (atoms $\mathrm{\AA^{-1}}$)")
ax.set_xlim(0, 6.6)
ax.set_xticks(np.arange(0, 6.6, 1))
ax.set_ylim(-2, 30)
ax.set_yticks(np.arange(0, 30.1, 10))
ax.legend()
ax.yaxis.set_tick_params(which='both', labelbottom=True, bottom=True, zorder=10)
ax.xaxis.set_tick_params(which='both', labelbottom=True, bottom=True, zorder=10)

plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

file_paths = [
    "rvv10_rdf_and_jr.txt",
    "rdf_as_beta.csv"
]

fig, ax = plt.subplots(figsize=(2.4, 2.4))
data = pd.read_csv(file_paths[0], delim_whitespace=True, skiprows=1, header=None)
x = data[0]
y = data[3]
plt.plot(x, y, color='purple', linestyle='-', label='r2SCAN+rVV10')

data = pd.read_csv(
    file_paths[1],
    sep=",",
    header=None,
    names=[0, 1],     
    skiprows=1,     
    engine="python"
)
x = data[0]
y = data[1]
plt.plot(x, y, color='gray', linestyle='--', dashes=[2, 1], label='Expt.')

ax.set_xlabel(r"Distance")
ax.set_ylabel(r"${J}$(${r}$) (atoms $\mathrm{\AA^{-1}}$)")
ax.set_xlim(0, 6.6)
ax.set_xticks(np.arange(0, 6.6, 1))
ax.set_ylim(-2, 30)
ax.set_yticks(np.arange(0, 30.1, 10))
ax.legend()
ax.yaxis.set_tick_params(which='both', labelbottom=True, bottom=True, zorder=10)
ax.xaxis.set_tick_params(which='both', labelbottom=True, bottom=True, zorder=10)

plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

file_paths = [
    "tpss_rdf_and_jr.txt",
    "rdf_as_beta.csv"
]

fig, ax = plt.subplots(figsize=(2.4, 2.4))
data = pd.read_csv(file_paths[0], delim_whitespace=True, skiprows=1, header=None)
x = data[0]
y = data[3]
plt.plot(x, y, color='blue', linestyle='-', label='TPSS')

data = pd.read_csv(
    file_paths[1],
    sep=",",
    header=None,
    names=[0, 1],     
    skiprows=1,     
    engine="python"
)
x = data[0]
y = data[1]
plt.plot(x, y, color='gray', linestyle='--', dashes=[2, 1], label='Expt.')

ax.set_xlabel(r"Distance")
ax.set_ylabel(r"${J}$(${r}$) (atoms $\mathrm{\AA^{-1}}$)")
ax.set_xlim(0, 6.6)
ax.set_xticks(np.arange(0, 6.6, 1))
ax.set_ylim(-2, 30)
ax.set_yticks(np.arange(0, 30.1, 10))
ax.legend()
ax.yaxis.set_tick_params(which='both', labelbottom=True, bottom=True, zorder=10)
ax.xaxis.set_tick_params(which='both', labelbottom=True, bottom=True, zorder=10)

plt.show()
