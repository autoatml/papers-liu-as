# %%
import matplotlib.pyplot as plt
import numpy as np

x1_rss, y1_rss = np.loadtxt('Sq_md_rss.txt', unpack=True)

x1_4000, y1_4000 = np.loadtxt('Sq_4000atoms.txt', unpack=True)

fig, ax = plt.subplots(figsize=(3, 3))

ax.plot(x1_4000, y1_4000, '-', label="4,000 atoms", color='red')

ax.plot(x1_rss,y1_rss,'--', label="2,000 atoms", color='blue')


ax.xaxis.set_tick_params(which='both', labelbottom=True, bottom=True)
ax.yaxis.set_tick_params(which='both', labelbottom=True, bottom=True)

plt.xlabel(r"${Q}$ ($\mathrm{\AA^{-1}}$)")
plt.ylabel(r"Structure factor")

ax.set_xlim(-1.5, 16)
ax.set_xticks(np.arange(0, 16.1, 4))
ax.set_ylim(0, 2.0)
ax.set_yticks(np.arange(0, 2.1, 1))
ax.legend(frameon=False)

for i in range(0,2,1):
    ax.axhline(y=i, linestyle='--', linewidth=0.65, color='gray',zorder=0)

plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

x1_rss, y1_rss = np.loadtxt('Sq_md_rss.txt', unpack=True)

x1_500ps, y1_500ps = np.loadtxt('Sq_500ps_anneal.txt', unpack=True)

fig, ax = plt.subplots(figsize=(3, 3))

ax.plot(x1_500ps, y1_500ps, '-', label="500 ps", color='red')
ax.plot(x1_rss,y1_rss,'--', label="50 ps", color='blue')


ax.xaxis.set_tick_params(which='both', labelbottom=True, bottom=True)
ax.yaxis.set_tick_params(which='both', labelbottom=True, bottom=True)

plt.xlabel(r"${Q}$ ($\mathrm{\AA^{-1}}$)")
plt.ylabel(r"Structure factor")

ax.set_xlim(-1.5, 16)
ax.set_xticks(np.arange(0, 16.1, 4))
ax.set_ylim(0, 2.0)
ax.set_yticks(np.arange(0, 2.1, 1))
ax.legend(frameon=False)

for i in range(0,2,1):
    ax.axhline(y=i, linestyle='--', linewidth=0.65, color='gray',zorder=0)

plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

x1_rss, y1_rss = np.loadtxt('Sq_10ns.txt', unpack=True)

x1_10ns, y1_10ns = np.loadtxt('Sq_md_rss.txt', unpack=True)

fig, ax = plt.subplots(figsize=(3, 3))

ax.plot(x1_rss,y1_rss,'-', label="$\mathrm{10^{11} Ks^{-1}}$", color='red')

ax.plot(x1_10ns, y1_10ns, '--', label="$\mathrm{10^{12} Ks^{-1}}$", color='blue')


ax.xaxis.set_tick_params(which='both', labelbottom=True, bottom=True)
ax.yaxis.set_tick_params(which='both', labelbottom=True, bottom=True)

plt.xlabel(r"${Q}$ ($\mathrm{\AA^{-1}}$)")
plt.ylabel(r"Structure factor")

ax.set_xlim(-1.5, 16)
ax.set_xticks(np.arange(0, 16.1, 4))
ax.set_ylim(0, 2.0)
ax.set_yticks(np.arange(0, 2.1, 1))
ax.legend(frameon=False)

for i in range(0,2,1):
    ax.axhline(y=i, linestyle='--', linewidth=0.65, color='gray',zorder=0)

plt.show()
